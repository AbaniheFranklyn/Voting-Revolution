# %%
import pandas as pd
import numpy as np
st = []
lg = []
r = 0.5
test = pd.read_csv('LGAs in Nigeria.csv')
#test.to_csv('test.csv',header=False)
#tested = pd.read_csv('test.csv').dropna(how='all').to_csv('rex.csv')
for i in test:
    st.append(i)
for i in st:
    for y in test[i]:
        if type(y) != type(r):
            print(y,i)
# Out:
# Aba North Abia
# Aba South Abia
# Arochukwu Abia
# Bende Abia
# Ikwuano Abia
# Isiala Ngwa North Abia
# Isiala Ngwa South Abia
# Isuikwato Abia
# Obi Ngwa Abia
# Ohafia Abia
# Osisioma Ngwa Abia
# Ugwunagbo Abia
# Ukwa East Abia
# Ukwa West Abia
# Umuahia North Abia
# Umuahia South Abia
# Umu-Nneochi Abia
# Demsa Adamawa
# Fufore Adamawa
# Ganye Adamawa
# Girei Adamawa
# Gombi Adamawa
# Guyuk Adamawa
# Hong Adamawa
# Jada Adamawa
# Lamurde Adamawa
# Madagali Adamawa
# Maiha Adamawa
# Mayo-Belwa Adamawa
# Michika Adamawa
# Mubi North Adamawa
# Mubi South Adamawa
# Numan Adamawa
# Shelleng Adamawa
# Song Adamawa
# Toungo Adamawa
# Yola North Adamawa
# Yola South Adamawa
# Abak Akwa Ibom
# Eastern Obolo Akwa Ibom
# Eket Akwa Ibom
# Esit-Eket Akwa Ibom
# Essien-Udim Akwa Ibom
# Etim-Ekpo Akwa Ibom
# Etinan Akwa Ibom
# Ibeno Akwa Ibom
# Ibesikpo-Asutan Akwa Ibom
# Ibiono-Ibom Akwa Ibom
# Ika Akwa Ibom
# Ikono Akwa Ibom
# Ikot Abassi Akwa Ibom
# Ikot Ekpene Akwa Ibom
# Ini Akwa Ibom
# ...
